# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('heart.csv')

# %%
df.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.drop_duplicates()
df.info
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
sns.countplot(x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
   sns.barplot(x='Sex',y='HeartDisease',data=df)
   plt.show()

# %% [markdown]
# Males (M) Heart Disease rate ~0.63 hai (63%)
# Females (F) Heart Disease rate ~0.26 hai (26%)

# %%
sns.barplot(x=df['Age'],y=df['Sex'],hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
sns.countplot(x='ChestPainType',hue='HeartDisease',data=df)
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x='FastingBS',hue='HeartDisease',data=df)
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
numeric=['Age',  'RestingBP', 'Cholesterol', 'FastingBS',
       'MaxHR', 'ExerciseAngina', 'Oldpeak',
       'HeartDisease']

# %%
for  nm in numeric:
   plt.figure(figsize=(6,4))
   sns.histplot(df[nm],kde=True,bins=20)

# %%
df[df['Cholesterol']==0].shape[0]
df['Cholesterol'].value_counts()
df['Cholesterol']
# Out:
# 0      289
# 1      180
# 2      283
# 3      214
# 4      195
#       ...
# 913    264
# 914    193
# 915    131
# 916    236
# 917    175
# Name: Cholesterol, Length: 918, dtype: int64

# %%
mean_c=df[df['Cholesterol'] != 0]['Cholesterol'].mean()
df['Cholesterol']=df['Cholesterol'].replace(0,mean_c)
df[df['Cholesterol']==0].shape[0]
# Out:
# 0

# %%
df[df['Cholesterol'] != 0]['Cholesterol']
# Out:
# 0      289.0
# 1      180.0
# 2      283.0
# 3      214.0
# 4      195.0
#        ...
# 913    264.0
# 914    193.0
# 915    131.0
# 916    236.0
# 917    175.0
# Name: Cholesterol, Length: 918, dtype: float64

# %%
numeric_col=['Age',   'RestingBP', 'Cholesterol', 
        'MaxHR',  'Oldpeak']

for n in numeric_col:
    plt.figure(figsize=(6,4))
    sns.boxplot(y=df[n],x=
       df['HeartDisease'])
    plt.show()

# %%
df.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140        289.0          0     Normal    172
# 1   49   F           NAP        160        180.0          0     Normal    156
# 2   37   M           ATA        130        283.0          0         ST     98
# 3   48   F           ASY        138        214.0          0     Normal    108
# 4   54   M           NAP        150        195.0          0     Normal    122
# 5   39   M           NAP        120        339.0          0     Normal    170
# 6   45   F           ATA        130        237.0          0     Normal    170
# 7   54   M           ATA        110        208.0          0     Normal    142
# 8   37   M           ASY        140        207.0          0     Normal    130
# 9   48   F           ATA        120        284.0          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
mean_rbp=df[df['RestingBP'] != 0]['RestingBP'].mean()
df['RestingBP']=df['RestingBP'].replace(0,mean_rbp)
df['RestingBP'].value_counts(ascending=True)
# Out:
# RestingBP
# 80.0       1
# 192.0      1
# 117.0      1
# 174.0      1
# 101.0      1
#         ...
# 150.0     55
# 110.0     58
# 140.0    107
# 130.0    118
# 120.0    132
# Name: count, Length: 67, dtype: int64

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde=True)
plotting('RestingBP',1) 
plotting('Cholesterol',2)

# %%
sns.violinplot(x='HeartDisease',y='Age',data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
df['FastingBS'].value_counts()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.263081     0.053373   0.198039 -0.382045  0.258612
# RestingBP     0.263081   1.000000     0.083076   0.067811 -0.109662  0.174220
# Cholesterol   0.053373   0.083076     1.000000   0.043008 -0.017239  0.053029
# FastingBS     0.198039   0.067811     0.043008   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.109662    -0.017239  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.174220     0.053029   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.117938     0.094071   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.117938
# Cholesterol       0.094071
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
pip install sheryanalysis
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sheryanalysis as sh

# %%
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# 📏 Shape: (918, 12)
# 🧱 Columns: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']
#
# ✅ No null values found
#
# 🔠 Categorical Columns: ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'HeartDisease']
#
# 🔢 Numerical Columns: ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
# {'shape': (918, 12),
#  'columns': ['Age',
#   'Sex',
#   'ChestPainType',
#   'RestingBP',
#   'Cholesterol',
#   'FastingBS',
#   'RestingECG',
#   'MaxHR',
#   'ExerciseAngina',
#   'Oldpeak',
#   'ST_Slope',
#   'HeartDisease'],
#  'dtypes': {'Age': dtype('int64'),
#   'Sex': dtype('O'),
#   'ChestPainType': dtype('O'),
#   'RestingBP': dtype('float64'),
#   'Cholesterol': dtype('float64'),
#   'FastingBS': dtype('int64'),
#   'RestingECG': dtype('O'),
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df_encode=pd.get_dummies(df,drop_first=True,)

# %%
df_encode=df_encode.astype(int)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
numeric_col_s=['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
scalar =StandardScaler()
df_encode[numeric_col_s]=scalar.fit_transform(df_encode[numeric_col_s])

# %%
df_encode
# Out:
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# 0   -1.433140   0.414885     0.834754          0  1.382928 -0.727592
# 1   -0.478484   1.527224    -1.210675          0  0.754157  0.282891
# 2   -1.751359  -0.141284     0.722161          0 -1.525138 -0.727592
# 3   -0.584556   0.303651    -0.572651          0 -1.132156  0.282891
# 4    0.051881   0.971054    -0.929194          0 -0.581981 -0.727592
# ..        ...        ...          ...        ...       ...       ...
# 913 -0.902775  -1.253622     0.365619          0 -0.188999  0.282891
# 914  1.536902   0.637353    -0.966725          1  0.164684  2.303858
# 915  0.370100  -0.141284    -2.130180          0 -0.857069  0.282891
# 916  0.370100  -0.141284    -0.159813          0  1.461525 -0.727592
# 917 -1.645286   0.303651    -1.304502          0  1.422226 -0.727592
#
#      HeartDisease  Sex_M  ChestPainType_ATA  ChestPainType_NAP  \
# 0               0      1                  1                  0
# ...
